# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
path1 = "plots/arch(Unet)-e(32)-l(MSE)-o(Adam)-lr(1e-05)_test_en.npy"
path2 = "plots/arch(Unet)-e(32)-l(MSE)-o(Adam)-lr(1e-05)_train_en.npy"
path3 = "plots/arch(Unet)-e(32)-l(MSE)-o(Adam)-lr(1e-05)_testn.npy"
path4 = "plots/arch(Unet)-e(32)-l(MSE)-o(Adam)-lr(1e-05)_trainn.npy"
path5 = "plots/arch(Unet)-e(32)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path6 = "plots/arch(Unet)-e(32)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path7 = "plots/arch(Unet)-e(32)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path8 = "plots/arch(Unet)-e(32)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"


data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)


#Convert to pandas dataframe
data3 = pd.DataFrame(data3, columns=['loss'])
data4 = pd.DataFrame(data4, columns=['loss'])
data7 = pd.DataFrame(data7, columns=['loss'])
data8 = pd.DataFrame(data8, columns=['loss'])

#Compute moving average
avg_data3 = data3.rolling(10000, min_periods=1).mean()
avg_data4 = data4.rolling(5000, min_periods=1).mean()
avg_data7 = data7.rolling(10000, min_periods=1).mean()
avg_data8 = data8.rolling(5000, min_periods=1).mean()


#Fig 1: Per Epoch
fig1, ax1 =  plt.subplots(figsize = (20,6))
ax1.plot(data1, color = 'tab:blue', linestyle = (0, (5,1)), label = 'Nrm_Voxel - Test')
ax1.plot(data2, color = 'tab:blue', label = 'Nrm_Voxel - Train')
ax1.plot(data5, color = 'tab:green', linestyle = (0, (5,1)), label = 'Mod_Voxel - Test')
ax1.plot(data6, color = 'tab:green', label = 'Mod_Voxel - Train')
#ax1.axhline(y=0.186, label='0.186 ')
ax1.legend()
ax1.legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss (MSE)")

#Fig 2: Per Batch
fig2, ax2 =  plt.subplots(1,2,figsize = (20,6))
ax2[0].plot(avg_data4, label = 'Nrm_Voxel - Train')
ax2[1].plot(avg_data3, label = 'Nrm_Voxel - Test')
ax2[0].plot(avg_data8, label = 'Mod_Voxel - Train')
ax2[1].plot(avg_data7, label = 'Mod_Voxel - Test')
ax2[0].set_ylim(.16, .24)
ax2[1].set_ylim(.16, .24)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Loss per batch", fontsize=15)
ax2[0].set_xlabel("Batch (moving average)")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Batch (moving average)")
ax2[1].set_ylabel("Loss (MSE)")

# %%
path1 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path2 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path3 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path4 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
path5 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_test_en.npy"
path6 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_train_en.npy"
path7 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_testn.npy"
path8 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_trainn.npy"


data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)

#Convert to pandas dataframe
data3 = pd.DataFrame(data3, columns=['loss'])
data4 = pd.DataFrame(data4, columns=['loss'])
data7 = pd.DataFrame(data7, columns=['loss'])
data8 = pd.DataFrame(data8, columns=['loss'])

#Compute moving average
avg_data3 = data3.rolling(5000, min_periods=1).mean()
avg_data4 = data4.rolling(5000, min_periods=1).mean()
avg_data7 = data7.rolling(5000, min_periods=1).mean()
avg_data8 = data8.rolling(5000, min_periods=1).mean()



fig1, ax1 =  plt.subplots(figsize = (20,6), )
#ax1.plot(data1, label = 'Test')
#ax1.plot(data2, label = 'Train')
ax1.plot(data5, label = 'Nrm_Voxel - Test')
ax1.plot(data6, label = 'Nrm_Voxel - Train')
#ax1.axhline(y=0.186, label='0.186 ')
ax1.legend()
ax1.legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss (MSE)")

fig2, ax2 =  plt.subplots(1,2,figsize = (20,6))
#ax2[0].plot(data3, label = 'Test')
#ax2[1].plot(data4, label = 'Train')
#ax2[0].plot(avg_data4, label = 'Train')
#ax2[1].plot(avg_data3, label = 'Test')
ax2[0].plot(avg_data8, label = 'Nrm_Voxel - Train')
ax2[1].plot(avg_data7, label = 'Nrm_Voxel - Test')
#ax2[0].axhline(y=0.186, color='r')
#ax2[1].axhline(y=0.186, color='r')
ax2[0].set_ylim(0.13, .2)
ax2[1].set_ylim(0.13, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Loss per batch", fontsize=15)
ax2[0].set_xlabel("Batch (moving average)")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Batch (moving average)")
ax2[1].set_ylabel("Loss (MSE)")

# %%
path1 = "plots/unnormalized/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path2 = "plots/unnormalized/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path3 = "plots/unnormalized/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path4 = "plots/unnormalized/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)

#Convert to pandas dataframe
data3 = pd.DataFrame(data3, columns=['loss'])
data4 = pd.DataFrame(data4, columns=['loss'])

#Compute moving average
avg_data3 = data3.rolling(5000, min_periods=1).mean()
avg_data4 = data4.rolling(5000, min_periods=1).mean()


fig1, ax1 =  plt.subplots(figsize = (20,6), )
ax1.plot(data1, label = 'Test')
ax1.plot(data2, label = 'Train')
#ax1.axhline(y=0.186, label='0.186 ')
ax1.legend()
ax1.legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss (MSE)")
fig1.savefig("plots/200e.png")

fig2, ax2 =  plt.subplots(1,2,figsize = (20,6))
#ax2[0].plot(data4, label = 'Train')
#ax2[1].plot(data3, label = 'Test')
ax2[0].plot(avg_data4, label = 'Train')
ax2[1].plot(avg_data3, label = 'Test')
#ax2[0].axhline(y=0.186, color='r')
#ax2[1].axhline(y=0.186, color='r')
ax2[0].set_ylim(0.05, .2)
ax2[1].set_ylim(0.05, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Loss per batch", fontsize=15)
ax2[0].set_xlabel("Batch (moving average)")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Batch (moving average)")
ax2[1].set_ylabel("Loss (MSE)")

# %%
#Normalized
path1 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy"
path3 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy"
path7 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path10= "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path11= "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path12= "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
path13= "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-06)_test_e.npy"
path14= "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-06)_train_e.npy"
path15= "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-06)_test.npy"
path16= "plots/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-06)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)
data13= np.load(path13)
data14= np.load(path14)
data15= np.load(path15)
data16= np.load(path16)

#Convert to pandas dataframe
data3 = pd.DataFrame(data3, columns=['loss'])
data7 = pd.DataFrame(data7, columns=['loss'])
data11 = pd.DataFrame(data11, columns=['loss'])
data15 = pd.DataFrame(data15, columns=['loss'])


#Compute moving average
avg_data3 = data3.rolling(10, min_periods=1).mean()
avg_data7 = data7.rolling(10, min_periods=1).mean()
avg_data11 = data11.rolling(10, min_periods=1).mean()
avg_data15 = data15.rolling(10, min_periods=1).mean()



fig1, ax1 =  plt.subplots(1,2,figsize = (20,6), )
ax1[0].plot(data1, label = '0.001')
ax1[1].plot(data2, label = '0.001')
ax1[0].plot(data5, label = '0.0001')
ax1[1].plot(data6, label = '0.0001')
ax1[0].plot(data9, label = '1e-5')
ax1[1].plot(data10, label = '1e-5')
ax1[0].plot(data13, label = '1e-6')
ax1[1].plot(data14, label = '1e-6')
#ax1.axhline(y=0.186, label='0.186 ')
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (MSE)")
ax1[0].set_title("Test")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (MSE)")
ax1[1].set_title("Train")

fig2, ax2 =  plt.subplots(figsize = (20,6))
ax2.plot(avg_data3, label = '0.001')
ax2.plot(avg_data7, label = '0.001')
ax2.plot(avg_data11, label = '0.001')
ax2.plot(avg_data15, label = '0.001')
#ax2.set_ylim(0.05, .2)
ax2.legend()
fig2.suptitle("Loss per batch", fontsize=15)
ax2.set_xlabel("Batch (moving average)")
ax2.set_ylabel("Loss (MSE)")

# %%
path1 = "plots/arch(Unet)-e(120)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path2 = "plots/arch(Unet)-e(120)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path3 = "plots/arch(Unet)-e(120)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path4 = "plots/arch(Unet)-e(120)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)

#Convert to pandas dataframe
data3 = pd.DataFrame(data3, columns=['loss'])
data4 = pd.DataFrame(data4, columns=['loss'])

#Compute moving average
avg_data3 = data3.rolling(5000, min_periods=1).mean()
avg_data4 = data4.rolling(5000, min_periods=1).mean()


fig1, ax1 =  plt.subplots(figsize = (20,6), )
ax1.plot(data1, label = 'Test')
ax1.plot(data2, label = 'Train')
#ax1.axhline(y=0.186, label='0.186 ')
ax1.legend()
ax1.legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss (MSE)")
fig1.savefig('plots/1vid.png')

fig2, ax2 =  plt.subplots(1,2,figsize = (20,6))
#ax2[0].plot(data4, label = 'Train')
#ax2[1].plot(data3, label = 'Test')
ax2[0].plot(avg_data4, label = 'Train')
ax2[1].plot(avg_data3, label = 'Test')
#ax2[0].axhline(y=0.186, color='r')
#ax2[1].axhline(y=0.186, color='r')
#ax2[0].set_ylim(0.05, .2)
#ax2[1].set_ylim(0.05, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Loss per batch", fontsize=15)
ax2[0].set_xlabel("Batch (moving average)")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Batch (moving average)")
ax2[1].set_ylabel("Loss (MSE)")

# %%
path1 = "plots/1vid/arch(Unet)-e(121)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path2 = "plots/1vid/arch(Unet)-e(121)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy"
path3 = "plots/1vid/arch(Unet)-e(121)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path4 = "plots/1vid/arch(Unet)-e(121)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)

#Convert to pandas dataframe
data3 = pd.DataFrame(data3, columns=['loss'])
data4 = pd.DataFrame(data4, columns=['loss'])

#Compute moving average
avg_data3 = data3.rolling(5000, min_periods=1).mean()
avg_data4 = data4.rolling(5000, min_periods=1).mean()


fig1, ax1 =  plt.subplots(figsize = (20,6), )
ax1.plot(data1, label = 'Test')
ax1.plot(data2, label = 'Train')
#ax1.axhline(y=0.186, label='0.186 ')
ax1.legend()
ax1.legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss (MSE)")
fig1.savefig('plots/1vid.png')

fig2, ax2 =  plt.subplots(1,2,figsize = (20,6))
#ax2[0].plot(data4, label = 'Train')
#ax2[1].plot(data3, label = 'Test')
ax2[0].plot(avg_data4, label = 'Train')
ax2[1].plot(avg_data3, label = 'Test')
#ax2[0].axhline(y=0.186, color='r')
#ax2[1].axhline(y=0.186, color='r')
#ax2[0].set_ylim(0.05, .2)
#ax2[1].set_ylim(0.05, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Loss per batch", fontsize=15)
ax2[0].set_xlabel("Batch (moving average)")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Batch (moving average)")
ax2[1].set_ylabel("Loss (MSE)")

# %%
#Normalized trained for 20 epochs on OTB100
path1 = "plots/arch(Unet)-e(20)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path2 = "plots/arch(Unet)-e(20)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path3 = "plots/arch(Unet)-e(20)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path4 = "plots/arch(Unet)-e(20)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)

#Convert to pandas dataframe
data3 = pd.DataFrame(data3, columns=['loss'])
data4 = pd.DataFrame(data4, columns=['loss'])

#Compute moving average
avg_data3 = data3.rolling(50, min_periods=1).mean()
avg_data4 = data4.rolling(50, min_periods=1).mean()


fig1, ax1 =  plt.subplots(figsize = (20,6), )
ax1.plot(data1, label = 'Test')
ax1.plot(data2, label = 'Train')
#ax1.axhline(y=0.186, label='0.186 ')
ax1.legend()
ax1.legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss (MSE)")
fig1.savefig('plots/norm.png')

fig2, ax2 =  plt.subplots(1,2,figsize = (20,6))
#ax2[0].plot(data4, label = 'Train')
#ax2[1].plot(data3, label = 'Test')
ax2[0].plot(avg_data4, label = 'Train')
ax2[1].plot(avg_data3, label = 'Test')
#ax2[0].axhline(y=0.186, color='r')
#ax2[1].axhline(y=0.186, color='r')
#ax2[0].set_ylim(0.05, .2)
#ax2[1].set_ylim(0.05, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Loss per batch", fontsize=15)
ax2[0].set_xlabel("Batch (moving average)")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Batch (moving average)")
ax2[1].set_ylabel("Loss (MSE)")

# %%
#Normalized trained on single video
path1 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy"
path3 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy"
path7 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path10= "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path11= "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path12= "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
path13= "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(1e-06)_test_e.npy"
path14= "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(1e-06)_train_e.npy"
path15= "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(1e-06)_test.npy"
path16= "plots/normalized_single/arch(Unet)-e(60)-l(MSE)-o(Adam)-lr(1e-06)_train.npy"
path17= "plots/normalized_single/arch(Unet)-e(50)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path18= "plots/normalized_single/arch(Unet)-e(50)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path19= "plots/normalized_single/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path20= "plots/normalized_single/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)
data13= np.load(path13)
data14= np.load(path14)
data15= np.load(path15)
data16= np.load(path16)
data17= np.load(path17)
data18= np.load(path18)
data19= np.load(path19)
data20= np.load(path20)


fig1, ax1 =  plt.subplots(1,2,figsize = (20,6), )
ax1[0].plot(data1, label = '0.001')
ax1[1].plot(data2, label = '0.001')
ax1[0].plot(data5, label = '0.0001')
ax1[1].plot(data6, label = '0.0001')
ax1[0].plot(data9, label = '1e-5')
ax1[1].plot(data10, label = '1e-5')
ax1[0].plot(data13, label = '1e-6')
ax1[1].plot(data14, label = '1e-6')
ax1[0].plot(data17, label = '1e-6')
ax1[1].plot(data18, label = '1e-6')
ax1[0].plot(data19, label = '1e-6')
ax1[1].plot(data20, label = '1e-6')
#ax1.axhline(y=0.186, label='0.186 ')
ax1[0].legend()
ax1[1].legend()
ax1[0].set_ylim(0, .2)
ax1[1].set_ylim(0, .2)
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (MSE)")
ax1[0].set_title("Test")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (MSE)")
ax1[1].set_title("Train")
ax1[0].set_ylim(0, .1)
ax1[1].set_ylim(0, .1)

fig1, ax1 =  plt.subplots(1,2,figsize = (20,6), )
ax1[0].plot(data3, label = '0.001')
ax1[1].plot(data4, label = '0.001')
ax1[0].plot(data7, label = '0.0001')
ax1[1].plot(data8, label = '0.0001')
ax1[0].plot(data11, label = '1e-5')
ax1[1].plot(data12, label = '1e-5')
ax1[0].plot(data15, label = '1e-5 Clip')
ax1[1].plot(data16, label = '1e-6')
#ax1.axhline(y=0.186, label='0.186 ')
ax1[0].legend()
ax1[1].legend()
ax1[0].set_ylim(0, .2)
ax1[1].set_ylim(0, .2)
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (MSE)")
ax1[0].set_title("Test")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (MSE)")
ax1[1].set_title("Train")

# %%
#Normalized on eventGAN clipping, trained on single
path1 = "plots/normalized_single_clip/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/normalized_single_clip/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/normalized_single_clip/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path4 = "plots/normalized_single_clip/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy"
path5 = "plots/normalized_single_clip/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path6 = "plots/normalized_single_clip/arch(Unet)-e(100)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"


data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)



fig1, ax1 =  plt.subplots(1,2,figsize = (20,6), )
ax1[0].plot(data1, label = '0.001')
ax1[1].plot(data2, label = '0.001')
ax1[0].plot(data3, label = '0.0001')
ax1[1].plot(data4, label = '0.0001')
ax1[0].plot(data5, label = '1e-05')
ax1[1].plot(data6, label = '1e-05')
#ax1.axhline(y=0.186, label='0.186 ')
ax1[0].legend()
ax1[1].legend()
ax1[0].set_ylim(0, .02)
ax1[1].set_ylim(0, .02)
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (MSE)")
ax1[0].set_title("Test")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (MSE)")
ax1[1].set_title("Train")

# %%
#Clipped trained in single video
path1 = "plots/clipped/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path2 = "plots/clipped/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path3 = "plots/clipped/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path4 = "plots/clipped/arch(Unet)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
path5 = "plots/clipped/arch(Unet)-e(300)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path6 = "plots/clipped/arch(Unet)-e(300)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path7 = "plots/clipped/arch(Unet)-e(300)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path8 = "plots/clipped/arch(Unet)-e(300)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)

#Convert to pandas dataframe
data3 = pd.DataFrame(data3, columns=['loss'])
data4 = pd.DataFrame(data4, columns=['loss'])

#Compute moving average
avg_data3 = data3.rolling(50, min_periods=1).mean()
avg_data4 = data4.rolling(50, min_periods=1).mean()


fig1, ax1 =  plt.subplots(figsize = (20,6), )
ax1.plot(data1, label = 'Test')
ax1.plot(data2, label = 'Train')
ax1.plot(data5, label = 'Test')
ax1.plot(data6, label = 'Train')
#ax1.axhline(y=0.186, label='0.186 ')
ax1.legend()
ax1.legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss (MSE)")
fig1.savefig('plots/norm.png')

fig2, ax2 =  plt.subplots(1,2,figsize = (20,6))
#ax2[0].plot(data4, label = 'Train')
#ax2[1].plot(data3, label = 'Test')
ax2[0].plot(avg_data4, label = 'Train')
ax2[1].plot(avg_data3, label = 'Test')
#ax2[0].axhline(y=0.186, color='r')
#ax2[1].axhline(y=0.186, color='r')
ax2[0].set_ylim(0.1, .4)
ax2[1].set_ylim(0.1, .4)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Loss per batch", fontsize=15)
ax2[0].set_xlabel("Batch (moving average)")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Batch (moving average)")
ax2[1].set_ylabel("Loss (MSE)")

# %%
#Clipped & normalized trained in single video
path1 = "plots/normalized_single_clip/arch(Unet)-e(250)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path2 = "plots/normalized_single_clip/arch(Unet)-e(250)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path3 = "plots/normalized_single_clip/arch(Unet)-e(250)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path4 = "plots/normalized_single_clip/arch(Unet)-e(250)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
path5 = "plots/normalized_single_clip/arch(Unet)-e(500)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path6 = "plots/normalized_single_clip/arch(Unet)-e(500)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy"
path7 = "plots/normalized_single_clip/arch(Unet)-e(500)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path8 = "plots/normalized_single_clip/arch(Unet)-e(500)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)



fig1, ax1 =  plt.subplots(figsize = (20,6), )
ax1.plot(data1, label = 'Test')
ax1.plot(data2, label = 'Train')
ax1.plot(data5, label = 'Test')
ax1.plot(data6, label = 'Train')
#ax1.axhline(y=0.186, label='0.186 ')
ax1.legend()
ax1.legend()
fig1.suptitle("Loss per Epoch", fontsize=15)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Loss (MSE)")
fig1.savefig('plots/norm.png')
