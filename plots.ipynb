# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#Normal Gaussian MSE
# path1 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
# path2 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
# path3 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
# path4 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
# path9 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
# path10 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
# path11 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
# path12 = "plots/single_gaussian/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
# path13 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
# path14 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
# path15 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
# path16 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path17 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path18 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path19 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path20 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
# path21 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
# path22 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
# path23 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
# path24 = "plots/single_gaussian/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
path25 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path26 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path27 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path28 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path29 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path30 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path31 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path32 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path33 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path34 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path35 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path36 = "plots/single_gaussian/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

# data1 = np.load(path1)
# data2 = np.load(path2)
# data3 = np.load(path3)
# data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
# data9 = np.load(path9)
# data10= np.load(path10)
# data11= np.load(path11)
# data12= np.load(path12)
# data13= np.load(path13)
# data14= np.load(path14)
# data15= np.load(path15)
# data16= np.load(path16)
data17= np.load(path17)
data18= np.load(path18)
data19= np.load(path19)
data20= np.load(path20)
# data21= np.load(path21)
# data22= np.load(path22)
# data23= np.load(path23)
# data24= np.load(path24)
data25= np.load(path25)
data26= np.load(path26)
data27= np.load(path27)
data28= np.load(path28)
data29= np.load(path29)
data30= np.load(path30)
data31= np.load(path31)
data32= np.load(path32)
data33= np.load(path33)
data34= np.load(path34)
data35= np.load(path35)
data36= np.load(path36)



fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
# ax1[1].plot(data1, label = '1e-03')
# ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
# ax1[1].plot(data9, label = '1e-05')
# ax1[0].plot(data10, label = '1e-05')
ax1[0].set_ylim(0, .1)
ax1[1].set_ylim(0, .1)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Normalized", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (MSE)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (MSE)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")

fig2, ax2 =  plt.subplots(1,2, figsize = (20,6), )
# ax2[1].plot(data13, label = '1e-03')
# ax2[0].plot(data14, label = '1e-03')
ax2[1].plot(data17, label = '1e-04')
ax2[0].plot(data18, label = '1e-04')
# ax2[1].plot(data21, label = '1e-05')
# ax2[0].plot(data22, label = '1e-05')
ax2[0].set_ylim(0, .2)
ax2[1].set_ylim(0, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Unnormalized", fontsize=15)
ax2[0].set_xlabel("Epoch")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Epoch")
ax2[1].set_ylabel("Loss (MSE)")
ax2[0].set_title("Train")
ax2[1].set_title("Test")

fig3, ax3 =  plt.subplots(1,2, figsize = (20,6), )
ax3[1].plot(data25, label = '1e-03')
ax3[0].plot(data26, label = '1e-03')
ax3[1].plot(data29, label = '1e-04')
ax3[0].plot(data30, label = '1e-04')
ax3[1].plot(data33, label = '1e-05')
ax3[0].plot(data34, label = '1e-05')
ax3[0].set_ylim(0, .2)
ax3[1].set_ylim(0, .2)
ax3[0].legend()
ax3[1].legend()
fig3.suptitle("Normalized [-1,1]", fontsize=15)
ax3[0].set_xlabel("Epoch")
ax3[0].set_ylabel("Loss (MSE)")
ax3[1].set_xlabel("Epoch")
ax3[1].set_ylabel("Loss (MSE)")
ax3[0].set_title("Train")
ax3[1].set_title("Test")

# %%
#Normal Gaussian L1
path1 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path10 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path11 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path12 = "plots/single_gaussian/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train.npy"
path13 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path14 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path15 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path16 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path17 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path18 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path19 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path20 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path21 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path22 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path23 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path24 = "plots/single_gaussian/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train.npy"
path25 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path26 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path27 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path28 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path29 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path30 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path31 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path32 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path33 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path34 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path35 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path36 = "plots/single_gaussian/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)
data13= np.load(path13)
data14= np.load(path14)
data15= np.load(path15)
data16= np.load(path16)
data17= np.load(path17)
data18= np.load(path18)
data19= np.load(path19)
data20= np.load(path20)
data21= np.load(path21)
data22= np.load(path22)
data23= np.load(path23)
data24= np.load(path24)
data25= np.load(path25)
data26= np.load(path26)
data27= np.load(path27)
data28= np.load(path28)
data29= np.load(path29)
data30= np.load(path30)
data31= np.load(path31)
data32= np.load(path32)
data33= np.load(path33)
data34= np.load(path34)
data35= np.load(path35)
data36= np.load(path36)



fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
ax1[1].plot(data1, label = '1e-03')
ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
ax1[1].plot(data9, label = '1e-05')
ax1[0].plot(data10, label = '1e-05')
ax1[0].set_ylim(0, .1)
ax1[1].set_ylim(0, .1)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Normalized", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (L1)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (L1)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")

fig2, ax2 =  plt.subplots(1,2, figsize = (20,6), )
ax2[1].plot(data13, label = '1e-03')
ax2[0].plot(data14, label = '1e-03')
ax2[1].plot(data17, label = '1e-04')
ax2[0].plot(data18, label = '1e-04')
ax2[1].plot(data21, label = '1e-05')
ax2[0].plot(data22, label = '1e-05')
ax2[0].set_ylim(0, .2)
ax2[1].set_ylim(0, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Unnormalized", fontsize=15)
ax2[0].set_xlabel("Epoch")
ax2[0].set_ylabel("Loss (L1)")
ax2[1].set_xlabel("Epoch")
ax2[1].set_ylabel("Loss (L1)")
ax2[0].set_title("Train")
ax2[1].set_title("Test")

fig3, ax3 =  plt.subplots(1,2, figsize = (20,6), )
ax3[1].plot(data25, label = '1e-03')
ax3[0].plot(data26, label = '1e-03')
ax3[1].plot(data29, label = '1e-04')
ax3[0].plot(data30, label = '1e-04')
ax3[1].plot(data33, label = '1e-05')
ax3[0].plot(data34, label = '1e-05')
ax3[0].set_ylim(0, .2)
ax3[1].set_ylim(0, .2)
ax3[0].legend()
ax3[1].legend()
fig3.suptitle("Normalized [-1,1]", fontsize=15)
ax3[0].set_xlabel("Epoch")
ax3[0].set_ylabel("Loss (L1)")
ax3[1].set_xlabel("Epoch")
ax3[1].set_ylabel("Loss (L1)")
ax3[0].set_title("Train")
ax3[1].set_title("Test")

# %%
#Small Gaussian MSE
path1 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path10 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path11 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path12 = "plots/single_gaussian_small/norm_mse/arch(NORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
path13 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path14 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path15 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path16 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path17 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path18 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path19 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path20 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path21 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path22 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path23 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path24 = "plots/single_gaussian_small/unnorm_mse/arch(UNORM)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"
path25 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path26 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path27 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path28 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path29 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path30 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path31 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path32 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path33 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path34 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path35 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path36 = "plots/single_gaussian_small/norm1_mse/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)
data13= np.load(path13)
data14= np.load(path14)
data15= np.load(path15)
data16= np.load(path16)
data17= np.load(path17)
data18= np.load(path18)
data19= np.load(path19)
data20= np.load(path20)
data21= np.load(path21)
data22= np.load(path22)
data23= np.load(path23)
data24= np.load(path24)
data25= np.load(path25)
data26= np.load(path26)
data27= np.load(path27)
data28= np.load(path28)
data29= np.load(path29)
data30= np.load(path30)
data31= np.load(path31)
data32= np.load(path32)
data33= np.load(path33)
data34= np.load(path34)
data35= np.load(path35)
data36= np.load(path36)



fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
ax1[1].plot(data1, label = '1e-03')
ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
ax1[1].plot(data9, label = '1e-05')
ax1[0].plot(data10, label = '1e-05')
ax1[0].set_ylim(0, .01)
ax1[1].set_ylim(0, .01)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Normalized", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (MSE)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (MSE)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")

fig2, ax2 =  plt.subplots(1,2, figsize = (20,6), )
ax2[1].plot(data13, label = '1e-03')
ax2[0].plot(data14, label = '1e-03')
ax2[1].plot(data17, label = '1e-04')
ax2[0].plot(data18, label = '1e-04')
ax2[1].plot(data21, label = '1e-05')
ax2[0].plot(data22, label = '1e-05')
ax2[0].set_ylim(0, .2)
ax2[1].set_ylim(0, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Unnormalized", fontsize=15)
ax2[0].set_xlabel("Epoch")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Epoch")
ax2[1].set_ylabel("Loss (MSE)")
ax2[0].set_title("Train")
ax2[1].set_title("Test")

fig3, ax3 =  plt.subplots(1,2, figsize = (20,6), )
ax3[1].plot(data25, label = '1e-03')
ax3[0].plot(data26, label = '1e-03')
ax3[1].plot(data29, label = '1e-04')
ax3[0].plot(data30, label = '1e-04')
ax3[1].plot(data33, label = '1e-05')
ax3[0].plot(data34, label = '1e-05')
ax3[0].set_ylim(0, .02)
ax3[1].set_ylim(0, .02)
ax3[0].legend()
ax3[1].legend()
fig3.suptitle("Normalized [-1,1]", fontsize=15)
ax3[0].set_xlabel("Epoch")
ax3[0].set_ylabel("Loss (MSE)")
ax3[1].set_xlabel("Epoch")
ax3[1].set_ylabel("Loss (MSE)")
ax3[0].set_title("Train")
ax3[1].set_title("Test")

# %%
#Small Gaussian L1
path1 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path10 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path11 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path12 = "plots/single_gaussian_small/norm_l1/arch(NORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train.npy"
path13 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path14 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path15 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path16 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path17 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path18 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path19 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path20 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path21 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path22 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path23 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path24 = "plots/single_gaussian_small/unnorm_l1/arch(UNORM)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train.npy"
path25 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path26 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path27 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path28 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path29 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path30 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path31 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path32 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path33 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path34 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path35 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path36 = "plots/single_gaussian_small/norm1_l1/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)
data13= np.load(path13)
data14= np.load(path14)
data15= np.load(path15)
data16= np.load(path16)
data17= np.load(path17)
data18= np.load(path18)
data19= np.load(path19)
data20= np.load(path20)
data21= np.load(path21)
data22= np.load(path22)
data23= np.load(path23)
data24= np.load(path24)
data25= np.load(path25)
data26= np.load(path26)
data27= np.load(path27)
data28= np.load(path28)
data29= np.load(path29)
data30= np.load(path30)
data31= np.load(path31)
data32= np.load(path32)
data33= np.load(path33)
data34= np.load(path34)
data35= np.load(path35)
data36= np.load(path36)



fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
ax1[1].plot(data1, label = '1e-03')
ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
ax1[1].plot(data9, label = '1e-05')
ax1[0].plot(data10, label = '1e-05')
#ax1[0].set_ylim(0, .1)
#ax1[1].set_ylim(0, .1)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Normalized", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (L1)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (L1)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")

fig2, ax2 =  plt.subplots(1,2, figsize = (20,6), )
ax2[1].plot(data13, label = '1e-03')
ax2[0].plot(data14, label = '1e-03')
ax2[1].plot(data17, label = '1e-04')
ax2[0].plot(data18, label = '1e-04')
ax2[1].plot(data21, label = '1e-05')
ax2[0].plot(data22, label = '1e-05')
#ax2[0].set_ylim(0, .2)
#ax2[1].set_ylim(0, .2)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Unnormalized", fontsize=15)
ax2[0].set_xlabel("Epoch")
ax2[0].set_ylabel("Loss (L1)")
ax2[1].set_xlabel("Epoch")
ax2[1].set_ylabel("Loss (L1)")
ax2[0].set_title("Train")
ax2[1].set_title("Test")

fig3, ax3 =  plt.subplots(1,2, figsize = (20,6), )
ax3[1].plot(data25, label = '1e-03')
ax3[0].plot(data26, label = '1e-03')
ax3[1].plot(data29, label = '1e-04')
ax3[0].plot(data30, label = '1e-04')
ax3[1].plot(data33, label = '1e-05')
ax3[0].plot(data34, label = '1e-05')
#ax3[0].set_ylim(0, .2)
#ax3[1].set_ylim(0, .2)
ax3[0].legend()
ax3[1].legend()
fig3.suptitle("Normalized [-1,1]", fontsize=15)
ax3[0].set_xlabel("Epoch")
ax3[0].set_ylabel("Loss (L1)")
ax3[1].set_xlabel("Epoch")
ax3[1].set_ylabel("Loss (L1)")
ax3[0].set_title("Train")
ax3[1].set_title("Test")

# %%
#Small Gaussian Tanh L1
path1 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path10 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path11 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path12 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(L1)-o(Adam)-lr(1e-05)_train.npy"
path13 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path14 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path15 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path16 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path17 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path18 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path19 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path20 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path21 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path22 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path23 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path24 = "plots/gaussian_tanh/arch(NORM1)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)
data13= np.load(path13)
data14= np.load(path14)
data15= np.load(path15)
data16= np.load(path16)
data17= np.load(path17)
data18= np.load(path18)
data19= np.load(path19)
data20= np.load(path20)
data21= np.load(path21)
data22= np.load(path22)
data23= np.load(path23)
data24= np.load(path24)


fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
ax1[1].plot(data1, label = '1e-03')
ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
ax1[1].plot(data9, label = '1e-05')
ax1[0].plot(data10, label = '1e-05')
ax1[0].set_ylim(0.05, .15)
ax1[1].set_ylim(0.05, .15)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Small Gaussian L1", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (L1)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (L1)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")

fig2, ax2 =  plt.subplots(1,2, figsize = (20,6), )
ax2[1].plot(data13, label = '1e-03')
ax2[0].plot(data14, label = '1e-03')
ax2[1].plot(data17, label = '1e-04')
ax2[0].plot(data18, label = '1e-04')
ax2[1].plot(data21, label = '1e-05')
ax2[0].plot(data22, label = '1e-05')
ax2[0].set_ylim(0.005, .03)
ax2[1].set_ylim(0.005, .03)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Small Gaussian MSE", fontsize=15)
ax2[0].set_xlabel("Epoch")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Epoch")
ax2[1].set_ylabel("Loss (MSE)")
ax2[0].set_title("Train")
ax2[1].set_title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
#Gaussian Tanh Normalized -1 1 
path1 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path10 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path11 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path12 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(1e-05)_train.npy"
path13 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path14 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path15 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path16 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path17 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path18 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path19 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path20 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path21 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path22 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path23 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path24 = "plots/gaussian_tanh/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)
data13= np.load(path13)
data14= np.load(path14)
data15= np.load(path15)
data16= np.load(path16)
data17= np.load(path17)
data18= np.load(path18)
data19= np.load(path19)
data20= np.load(path20)
data21= np.load(path21)
data22= np.load(path22)
data23= np.load(path23)
data24= np.load(path24)


fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
ax1[1].plot(data1, label = '1e-03')
ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
ax1[1].plot(data9, label = '1e-05')
ax1[0].plot(data10, label = '1e-05')
ax1[0].set_ylim(0.05, .15)
ax1[1].set_ylim(0.05, .15)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Gaussian L1", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (L1)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (L1)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")

fig2, ax2 =  plt.subplots(1,2, figsize = (20,6), )
ax2[1].plot(data13, label = '1e-03')
ax2[0].plot(data14, label = '1e-03')
ax2[1].plot(data17, label = '1e-04')
ax2[0].plot(data18, label = '1e-04')
ax2[1].plot(data21, label = '1e-05')
ax2[0].plot(data22, label = '1e-05')
ax2[0].set_ylim(0.005, .03)
ax2[1].set_ylim(0.005, .03)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Gaussian MSE", fontsize=15)
ax2[0].set_xlabel("Epoch")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Epoch")
ax2[1].set_ylabel("Loss (MSE)")
ax2[0].set_title("Train")
ax2[1].set_title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
#Gaussian Tanh Unnormalized
path1 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(1e-05)_test_e.npy"
path10 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(1e-05)_train_e.npy" 
path11 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(1e-05)_test.npy"
path12 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(L1)-o(Adam)-lr(1e-05)_train.npy"
path13 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path14 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path15 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path16 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path17 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path18 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path19 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path20 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path21 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path22 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path23 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path24 = "plots/gaussian_tanh/unnorm/arch(NORM1)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)
data13= np.load(path13)
data14= np.load(path14)
data15= np.load(path15)
data16= np.load(path16)
data17= np.load(path17)
data18= np.load(path18)
data19= np.load(path19)
data20= np.load(path20)
data21= np.load(path21)
data22= np.load(path22)
data23= np.load(path23)
data24= np.load(path24)


fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
ax1[1].plot(data1, label = '1e-03')
ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
ax1[1].plot(data9, label = '1e-05')
ax1[0].plot(data10, label = '1e-05')
ax1[0].set_ylim(0, .2)
ax1[1].set_ylim(0, .2)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Gaussian L1", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (L1)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (L1)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")

fig2, ax2 =  plt.subplots(1,2, figsize = (20,6), )
ax2[1].plot(data13, label = '1e-03')
ax2[0].plot(data14, label = '1e-03')
ax2[1].plot(data17, label = '1e-04')
ax2[0].plot(data18, label = '1e-04')
ax2[1].plot(data21, label = '1e-05')
ax2[0].plot(data22, label = '1e-05')
ax2[0].set_ylim(0, .35)
ax2[1].set_ylim(0, .35)
ax2[0].legend()
ax2[1].legend()
fig2.suptitle("Gaussian MSE", fontsize=15)
ax2[0].set_xlabel("Epoch")
ax2[0].set_ylabel("Loss (MSE)")
ax2[1].set_xlabel("Epoch")
ax2[1].set_ylabel("Loss (MSE)")
ax2[0].set_title("Train")
ax2[1].set_title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
#Gaussian small weighted MSE
path1 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path10 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path11 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path12 = "plots/wmse/arch(UNORM_WMSE)-e(200)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)


fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
ax1[1].plot(data1, label = '1e-03')
ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
ax1[1].plot(data9, label = '1e-05')
ax1[0].plot(data10, label = '1e-05')
ax1[0].set_ylim(0, .5)
ax1[1].set_ylim(0, .5)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Gaussian L1", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (L1)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (L1)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
#Gaussian weighted MSE
path1 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(0.001)_test_e.npy"
path2 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(0.001)_train_e.npy" 
path3 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(0.001)_test.npy"
path4 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(0.001)_train.npy"
path5 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_test_e.npy"
path6 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_train_e.npy" 
path7 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_test.npy"
path8 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(0.0001)_train.npy"
path9 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_test_e.npy"
path10 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_train_e.npy" 
path11 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_test.npy"
path12 = "plots/wmse/arch(UNORM_WMSE)-e(201)-l(MSE)-o(Adam)-lr(1e-05)_train.npy"

data1 = np.load(path1)
data2 = np.load(path2)
data3 = np.load(path3)
data4 = np.load(path4)
data5 = np.load(path5)
data6 = np.load(path6)
data7 = np.load(path7)
data8 = np.load(path8)
data9 = np.load(path9)
data10= np.load(path10)
data11= np.load(path11)
data12= np.load(path12)


fig1, ax1 =  plt.subplots(1,2, figsize = (20,6), )
ax1[1].plot(data1, label = '1e-03')
ax1[0].plot(data2, label = '1e-03')
ax1[1].plot(data5, label = '1e-04')
ax1[0].plot(data6, label = '1e-04')
ax1[1].plot(data9, label = '1e-05')
ax1[0].plot(data10, label = '1e-05')
ax1[0].set_ylim(0, .5)
ax1[1].set_ylim(0, .5)
ax1[0].legend()
ax1[1].legend()
fig1.suptitle("Gaussian L1", fontsize=15)
ax1[0].set_xlabel("Epoch")
ax1[0].set_ylabel("Loss (L1)")
ax1[1].set_xlabel("Epoch")
ax1[1].set_ylabel("Loss (L1)")
ax1[0].set_title("Train")
ax1[1].set_title("Test")
# Out:
# Text(0.5, 1.0, 'Test')
